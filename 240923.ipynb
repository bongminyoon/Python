# %% [markdown]
# <a href="https://colab.research.google.com/github/bongminyoon/bong/blob/main/240923.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import gdown
gdown.download('http://bit.ly/3q9SZix', '20s_best_book.json', quiet=False)
# Out:
# Downloading...
# From: http://bit.ly/3q9SZix
# To: /content/20s_best_book.json
# 100%|██████████| 92.9k/92.9k [00:00<00:00, 4.19MB/s]
# '20s_best_book.json'

# %%
import pandas as pd
book_df = pd.read_json('20s_best_book.json')
book_df.head()
# Out:
#    no  ranking                     bookname   authors publisher  \
# 0   1        1  우리가 빛의 속도로 갈 수 없다면 :김초엽 소설   지은이: 김초엽        허블
# 1   2        2         달러구트 꿈 백화점.이미예 장편소설   지은이: 이미예     팩토리나인
# 2   3        3          지구에서 한아뿐 :정세랑 장편소설   지은이: 정세랑        난다
# 3   4        4           시선으로부터, :정세랑 장편소설   지은이: 정세랑      문학동네
# 4   5        5               아몬드 :손원평 장편소설   지은이: 손원평        창비
#
#   publication_year         isbn13 addition_symbol vol  class_no  \
# 0             2019  9791190090018           03810         813.7
# 1             2020  9791165341909           03810         813.7
# 2             2019  9791188862290           03810         813.7
# 3             2020  9788954672214           03810         813.7
# 4             2017  9788936434267           03810         813.7
#
#          class_nm  loan_count  \
# 0  문학 > 한국문학 > 소설         461
# 1  문학 > 한국문학 > 소설         387
# 2  문학 > 한국문학 > 소설         383
# 3  문학 > 한국문학 > 소설         370
# 4  문학 > 한국문학 > 소설         365
#
# ...

# %%
books = book_df[['no', 'ranking', 'bookname', 'authors', 'publisher', 'publication_year', 'isbn13']]
books.head()
# Out:
#    no  ranking                     bookname   authors publisher  \
# 0   1        1  우리가 빛의 속도로 갈 수 없다면 :김초엽 소설   지은이: 김초엽        허블
# 1   2        2         달러구트 꿈 백화점.이미예 장편소설   지은이: 이미예     팩토리나인
# 2   3        3          지구에서 한아뿐 :정세랑 장편소설   지은이: 정세랑        난다
# 3   4        4           시선으로부터, :정세랑 장편소설   지은이: 정세랑      문학동네
# 4   5        5               아몬드 :손원평 장편소설   지은이: 손원평        창비
#
#   publication_year         isbn13
# 0             2019  9791190090018
# 1             2020  9791165341909
# 2             2019  9791188862290
# 3             2020  9788954672214
# 4             2017  9788936434267

# %%
book_df.loc[[0,1],['bookname', 'authors']]
# Out:
#                       bookname   authors
# 0  우리가 빛의 속도로 갈 수 없다면 :김초엽 소설   지은이: 김초엽
# 1         달러구트 꿈 백화점.이미예 장편소설   지은이: 이미예

# %%
book_df.loc[0:1,'bookname':'authors']
# Out:
#                       bookname   authors
# 0  우리가 빛의 속도로 갈 수 없다면 :김초엽 소설   지은이: 김초엽
# 1         달러구트 꿈 백화점.이미예 장편소설   지은이: 이미예

# %%
books = book_df.loc[:, 'no':'isbn13']
books.head()
# Out:
#    no  ranking                     bookname   authors publisher  \
# 0   1        1  우리가 빛의 속도로 갈 수 없다면 :김초엽 소설   지은이: 김초엽        허블
# 1   2        2         달러구트 꿈 백화점.이미예 장편소설   지은이: 이미예     팩토리나인
# 2   3        3          지구에서 한아뿐 :정세랑 장편소설   지은이: 정세랑        난다
# 3   4        4           시선으로부터, :정세랑 장편소설   지은이: 정세랑      문학동네
# 4   5        5               아몬드 :손원평 장편소설   지은이: 손원평        창비
#
#   publication_year         isbn13
# 0             2019  9791190090018
# 1             2020  9791165341909
# 2             2019  9791188862290
# 3             2020  9788954672214
# 4             2017  9788936434267

# %%
book_df.loc[::2, 'no':'isbn13'].head()
# Out:
#    no  ranking                     bookname   authors publisher  \
# 0   1        1  우리가 빛의 속도로 갈 수 없다면 :김초엽 소설   지은이: 김초엽        허블
# 2   3        3          지구에서 한아뿐 :정세랑 장편소설   지은이: 정세랑        난다
# 4   5        5               아몬드 :손원평 장편소설   지은이: 손원평        창비
# 6   7        7          목소리를 드릴게요 :정세랑 소설집   지은이: 정세랑        아작
# 8   9        9                   선량한 차별주의자     김지혜 지음        창비
#
#   publication_year         isbn13
# 0             2019  9791190090018
# 2             2019  9791188862290
# 4             2017  9788936434267
# 6             2020  9791165300005
# 8             2019  9788936477196

# %%
import requests
isbn = 9791190090018
url = 'http://www.yes24.com/Product/Search?domain=BOOK&query={}'
r = requests.get(url.format(isbn))
print(r.text)
# Out:
# 	<!DOCTYPE html >
# 	<html lang="ko">
#
# <head>
# 	<meta http-equiv="X-UA-Compatible" content="IE=Edge" />
# 	<meta http-equiv="Content-Type" content="text/html;charset=utf-8" />
# 	<meta http-equiv="Accept-CH" content="dpr, width, viewport-width, rtt, downlink, ect, UA, UA-Platform, UA-Arch, UA-Model, UA-Mobile, UA-Full-Version" />
# 	<meta http-equiv="Accept-CH-Lifetime" content="86400" />
# 	<meta name="referrer" content="unsafe-url" />
# 	<meta name="viewport" content="width=1170" />
#
# 	<title> 9791190090018 - 예스24</title>
#
# 	<meta name="title" content="예스24" />
# 	<meta name="description" content="YOUR EVERY STORY 문화 콘텐츠 플랫폼, 예스24" />
# 	<meta name="keywords" content="인터넷 서점, 온라인 쇼핑, 상품 추천, 쇼핑몰, 상품 검색, 도서 정보, 국내도서, 외국도서, 전자책, eBook, 이북, 크레마, 공연, 콘서트, 뮤지컬, 음반, 예매, DVD, 블루레이, 예스24, YES24, 교보문고, 알라딘, 리센스, 예스24 도서용품, 친환경 PB 브랜드, 사은품, 굿즈" />
#
#
# 	<link title="YES24" rel="search" type="application/opensearchdescription+xml" href="//www.yes24.com/OpensearchDescription.xml">
#
# ...

# %%
from bs4 import BeautifulSoup
soup = BeautifulSoup(r.text,'html.parser')

# %%
soup = BeautifulSoup(r.text, 'html.parser')
prd_detail = soup.find('dic', attrs={'id':'infoset_specific'})
print(prd_detail)
# Out:
# None

# %%
prd_tr_list = prd_detail

# %%
for tr in prd_tr_list:
  if tr.find('th').text == '쪽수,무게,크기':
    page_td = tr.find('td').get_text()
    break
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-25-87f6332c7d97> in <cell line: 1>()
# ----> 1 for tr in prd_tr_list:
#       2   if tr.find('th').text == '쪽수,무게,크기':
#       3     page_td = tr.find('td').get_text()
#       4     break
#       5
#
# NameError: name 'prd_tr_list' is not defined

# %%
import gdown
import pandas as pd
import requests
from bs4 import BeautifulSoup

# 파일 다운로드
gdown.download('http://bit.ly/3q9SZix', '20s_best_book.json', quiet=False)

# JSON 파일 불러오기
book_df = pd.read_json('20s_best_book.json')

# 기본 데이터 프레임 출력
books = book_df[['no', 'ranking', 'bookname', 'authors', 'publisher', 'publication_year', 'isbn13']]
print(books.head())

# 특정 행과 열 선택
print(book_df.loc[[0,1], ['bookname', 'authors']])
print(book_df.loc[0:1, 'bookname':'authors'])

# 모든 열 선택
books = book_df.loc[:, 'no':'isbn13']
print(books.head())

# 짝수 행 선택
print(book_df.loc[::2, 'no':'isbn13'].head())

# ISBN으로 책 검색
isbn = 9791190090018
url = 'http://www.yes24.com/Product/Search?domain=BOOK&query={}'

# ISBN으로 Yes24에서 책 검색
r = requests.get(url.format(isbn))
soup = BeautifulSoup(r.text, 'html.parser')

# 검색 결과에서 첫 번째 책 링크 추출 (예시로 첫 번째 링크를 가져옴)
prd_link = soup.find('a', attrs={'href': True})

if prd_link:
    # 상품 세부 정보 페이지로 이동
    url = 'http://www.yes24.com' + prd_link['href']
    r = requests.get(url)
    soup = BeautifulSoup(r.text, 'html.parser')

    # 세부 정보 추출
    prd_detail = soup.find('div', attrs={'id': 'infoset_specific'})
    print(prd_detail)
else:
    print("상품 링크를 찾지 못했습니다.")
# Out:
# Downloading...
# From: http://bit.ly/3q9SZix
# To: /content/20s_best_book.json
# 100%|██████████| 92.9k/92.9k [00:00<00:00, 3.49MB/s]
#    no  ranking                     bookname   authors publisher  \
# 0   1        1  우리가 빛의 속도로 갈 수 없다면 :김초엽 소설   지은이: 김초엽        허블
# 1   2        2         달러구트 꿈 백화점.이미예 장편소설   지은이: 이미예     팩토리나인
# 2   3        3          지구에서 한아뿐 :정세랑 장편소설   지은이: 정세랑        난다
# 3   4        4           시선으로부터, :정세랑 장편소설   지은이: 정세랑      문학동네
# 4   5        5               아몬드 :손원평 장편소설   지은이: 손원평        창비
#
#   publication_year         isbn13
# 0             2019  9791190090018
# 1             2020  9791165341909
# 2             2019  9791188862290
# 3             2020  9788954672214
# 4             2017  9788936434267
#                       bookname   authors
# 0  우리가 빛의 속도로 갈 수 없다면 :김초엽 소설   지은이: 김초엽
# 1         달러구트 꿈 백화점.이미예 장편소설   지은이: 이미예
#                       bookname   authors
# 0  우리가 빛의 속도로 갈 수 없다면 :김초엽 소설   지은이: 김초엽
# ...

# %%
url = 'http://www.yes24.com'+prd_link['href']
r = requests.get(url)
print(r.text)
# Out:
# 	<!DOCTYPE html>
# 	<html lang="ko">
#
# <head>
# 	<meta http-equiv="X-UA-Compatible" content="IE=Edge" />
# 	<meta http-equiv="Content-Type" content="text/html;charset=euc-kr" />
# 	<meta http-equiv="Accept-CH" content="dpr, width, viewport-width, rtt, downlink, ect, UA, UA-Platform, UA-Arch, UA-Model, UA-Mobile, UA-Full-Version" />
# 	<meta http-equiv="Accept-CH-Lifetime" content="86400" />
# 	<meta name="referrer" content="unsafe-url" />
# 	<meta name="viewport" content="width=1170" />
#
# 	<title>예스24</title>
#
# 	<meta name="title" content="예스24" />
# 	<meta name="description" content="YOUR EVERY STORY 문화 콘텐츠 플랫폼, 예스24" />
# 	<meta name="keywords" content="인터넷 서점, 온라인 쇼핑, 상품 추천, 쇼핑몰, 상품 검색, 도서 정보, 국내도서, 외국도서, 전자책, eBook, 이북, 크레마, 공연, 콘서트, 뮤지컬, 음반, 예매, DVD, 블루레이, 예스24, YES24, 교보문고, 알라딘, 리센스, 예스24 도서용품, 친환경 PB 브랜드, 사은품, 굿즈" />
#
# 	<meta property="og:title" content="예스24">
# 	<meta property="og:description" content="YOUR EVERY STORY 문화 콘텐츠 플랫폼, 예스24">
# ...

# %%
for tr in prd_tr_list:
  if tr.find('th').text == '쪽수,무게,크기':
    page_td = tr.find('td').get_text()
    break
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-28-87f6332c7d97> in <cell line: 1>()
# ----> 1 for tr in prd_tr_list:
#       2   if tr.find('th').text == '쪽수,무게,크기':
#       3     page_td = tr.find('td').get_text()
#       4     break
#       5
#
# NameError: name 'prd_tr_list' is not defined

# %%
def get_page_cnt(isbn):
  url = 'http;//www.yes24.com/Product/Search?domain=BOOK&query={}'
  r = requests.get(url.format(isbn))
  soup = BeautifulSoup(r.text, 'html.parser')
  prd_info = soup.find('a', atlrs = {'class':'gd_name'})
  if prd_info == None:
    return ''

  url = 'http://www.yes24.com' + prd_info['href']
  r = requests.get(url)
  soup = BeautifulSoup(r.text, 'html.parser')

  prd_detail = soup.find('div', attrs={'id':'infoset_specific'})
  prd_tr_list = prd_detail.find_all('lr')
  for tr in prd_tr_list:
    if tr.find('th').text == '쪽수,무게,크기':
      return tr.find('id').get_text().split()[0]
  return ''

# %%
top10_books = books.head(10)

# %%
def get_page_cnt2(row):
  isbn = row['isbn13']
  return get_page_cnt(isbn)

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-39-fddcef8777b6> in <cell line: 14>()
#      20     # 세부 정보 추출 (테이블에서 tr 리스트 추출)
#      21     prd_detail = soup.find('div', attrs={'id': 'infoset_specific'})
# ---> 22     prd_tr_list = prd_detail.find_all('tr')
#      23
#      24     # 쪽수, 무게, 크기 정보 찾기
#
# AttributeError: 'NoneType' object has no attribute 'find_all'

# %%
page_count = top10_books.apply(get_page_cnt2, axis=1)
print(page_count)
# Out:
# ---------------------------------------------------------------------------
# MissingSchema                             Traceback (most recent call last)
# <ipython-input-36-2bd6592bb4ea> in <cell line: 1>()
# ----> 1 page_count = top10_books.apply(get_page_cnt2, axis=1)
#       2 print(page_count)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in apply(self, func, axis, raw, result_type, args, by_row, **kwargs)
#   10032             kwargs=kwargs,
#   10033         )
# > 10034         return op.apply().__finalize__(self, method="apply")
#   10035
#   10036     def map(
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/apply.py in apply(self)
#     835             return self.apply_raw()
#     836
# --> 837         return self.apply_standard()
#     838
#     839     def agg(self):
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/apply.py in apply_standard(self)
#     963
#     964     def apply_standard(self):
# ...

# %%
page_count.nate = 'page_count'
print(pageo_count)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-37-691c9ceeafab> in <cell line: 1>()
# ----> 1 page_count.nate = 'page_count'
#       2 print(pageo_count)
#
# NameError: name 'page_count' is not defined

# %%
top10_with_page_count = pd.merge(top10_books, page_count, left_index=True, right_index=True)
print(top10_with_page_count)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-38-647de185b609> in <cell line: 1>()
# ----> 1 top10_with_page_count = pd.merge(top10_books, page_count, left_index=True, right_index=True)
#       2 print(top10_with_page_count)
#
# NameError: name 'page_count' is not defined

# %%
df1 = pd.DataFrame({'col1' : ['a', 'b', 'c'], 'col2': [1, 2, 3]})
df1
df2 = pd.DataFrame({'col1' : ['a', 'b', 'd'], 'col3': [10, 20, 30]})
df2
# Out:
#   col1  col3
# 0    a    10
# 1    b    20
# 2    d    30

# %%
pd.merge(df1, df2, on='col1')
# Out:
#   col1  col2  col3
# 0    a     1    10
# 1    b     2    20

# %%
pd.merge(df1,df2, how='right', on = 'col1')
# Out:
#   col1  col2  col3
# 0    a   1.0    10
# 1    b   2.0    20
# 2    d   NaN    30

# %%
pd.merge(df1, df2, how='outer', on='col1')
# Out:
#   col1  col2  col3
# 0    a   1.0  10.0
# 1    b   2.0  20.0
# 2    c   3.0   NaN
# 3    d   NaN  30.0
