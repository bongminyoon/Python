# %% [markdown]
# <a href="https://colab.research.google.com/github/bongminyoon/bong/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 인공지능 모델

# %%
import tensorflow as tf
import pandas as pd

# %%
# 파일들로 부터 데이터 읽어오기

파일경로 = 'https://raw.githubusercontent.com/bongminyoon/bong/main/lemonade%20(2).csv'
레모네이드 = pd.read_csv(파일경로)

# %%
# 변수안에 어떤데이터가 있는지 확인 (데이터 모양으로 확인

print(레모네이드.shape)
# Out:
# (6, 2)

# %%
# 칼럼 이름 출력

print(레모네이드.columns)
# Out:
# Index(['온도', '판매량'], dtype='object')

# %%
# 독립 (영향을 주는 요소들) / 종속변수 (결과)

독립 = 레모네이드[['온도']]
종속 = 레모네이드[['판매량']]
print(독립.shape, 종속.shape)
# Out:
# (6, 1) (6, 1)

# %%
# 실제데이터 출력

레모네이드.head()

# %%
# 모델을 만듭니다

X = tf.keras.layers.Input(shape=[1])
Y = tf.keras.layers.Dense(1)(X)
model = tf.keras.models.Model(X,Y)
model.compile(loss='mse')

# %%
model.fit(독립, 종속, epochs=1000)
# Out:
# Epoch 1/1000
# 1/1 [==============================] - 0s 13ms/step - loss: 82.4939
# Epoch 2/1000
# 1/1 [==============================] - 0s 12ms/step - loss: 82.0763
# Epoch 3/1000
# 1/1 [==============================] - 0s 13ms/step - loss: 81.6597
# Epoch 4/1000
# 1/1 [==============================] - 0s 11ms/step - loss: 81.2442
# Epoch 5/1000
# 1/1 [==============================] - 0s 11ms/step - loss: 80.8298
# Epoch 6/1000
# 1/1 [==============================] - 0s 11ms/step - loss: 80.4166
# Epoch 7/1000
# 1/1 [==============================] - 0s 13ms/step - loss: 80.0043
# Epoch 8/1000
# 1/1 [==============================] - 0s 14ms/step - loss: 79.5932
# Epoch 9/1000
# 1/1 [==============================] - 0s 13ms/step - loss: 79.1831
# Epoch 10/1000
# 1/1 [==============================] - 0s 11ms/step - loss: 78.7742
# Epoch 11/1000
# 1/1 [==============================] - 0s 19ms/step - loss: 78.3663
# Epoch 12/1000
# ...

# %%
 model.predict([[15]])
# Out:
# 1/1 [==============================] - 0s 71ms/step
# array([[30.991976]], dtype=float32)
